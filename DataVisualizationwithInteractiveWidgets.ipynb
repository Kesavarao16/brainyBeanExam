# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive

# %%
# Function to plot sine wave with varying frequency
def plot_sine_wave(frequency=1):
    x = np.linspace(0, 10, 1000)
    y = np.sin(frequency * x)
    plt.figure(figsize=(8, 4))
    plt.plot(x, y)
    plt.title(f"Sine Wave with Frequency {frequency}")
    plt.xlabel("X")
    plt.ylabel("Sin(x)")
    plt.grid(True)
    plt.show()

# %%
# Create an interactive slider
interactive_plot = interactive(plot_sine_wave, frequency=(1, 10, 1))
interactive_plot
# Out:
# interactive(children=(IntSlider(value=1, description='frequency', max=10, min=1), Output()), _dom_classes=('wi…
